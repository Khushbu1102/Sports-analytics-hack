# %% [markdown]
# # 03 Benchmark Modeling
#
# - Compare start-only, early, and full views.
# - Keep validation grouped by `match_id`.
# - Log assumptions for logistic regression and XGBoost baselines.
